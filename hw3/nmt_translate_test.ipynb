# %% [markdown]
# #---------------------------------------------------------------------
#
# '''
# Neural Machine Translation - Translation experiments
#     Training, evaluation and prediction functions
# '''
#
# #---------------------------------------------------------------------

# %%
import numpy as np
import chainer
from chainer import cuda, Function, gradient_check, report, training, utils, Variable
from chainer import datasets, iterators, optimizers, serializers
from chainer import Link, Chain, ChainList
import chainer.functions as F
import chainer.links as L
from chainer.training import extensions
from tqdm import tqdm
import sys
import os
from collections import Counter
import math
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import time
import matplotlib.gridspec as gridspec
import importlib
import matplotlib.mlab as mlab
import seaborn as sns
# %matplotlib inline
# %matplotlib inline

# %%
#---------------------------------------------------------------------
# Load configuration
#---------------------------------------------------------------------
from nmt_config import *
# Out:
# Inuktitut English dataset configuration

# %%
#---------------------------------------------------------------------
# Load encoder decoder model definition
#---------------------------------------------------------------------
from enc_dec_batch import *

# %%
xp = cuda.cupy if gpuid >= 0 else np

# %%
#---------------------------------------------------------------------
# Load dataset
#---------------------------------------------------------------------
w2i = pickle.load(open(w2i_path, "rb"))
i2w = pickle.load(open(i2w_path, "rb"))
vocab = pickle.load(open(vocab_path, "rb"))
vocab_size_en = min(len(i2w["en"]), max_vocab_size["en"])
vocab_size_fr = min(len(i2w["fr"]), max_vocab_size["fr"])
print("vocab size, en={0:d}, fr={1:d}".format(vocab_size_en, vocab_size_fr))
print("{0:s}".format("-"*50))
#---------------------------------------------------------------------
# Out:
# vocab size, en=9363, fr=64858
# --------------------------------------------------

# %%
sentence_length={"len_fr":[],"len_en":[]}
en_token={}
fr_token={}
with open(text_fname["fr"], "rb") as fr_file, open(text_fname["en"], "rb") as en_file:
    for i, (line_fr, line_en) in enumerate(zip(fr_file, en_file), start=1):
        sentence_length['len_fr'].append(len(line_fr))
        sentence_length['len_en'].append(len(line_en))
        #print(line_en)
        for token in line_fr.split():
            #print(token)
            if token in fr_token:
                fr_token[token] += 1
            else:
                fr_token[token] = 1
        for token in line_en.split():
            if token in en_token:
                en_token[token] += 1
            else:
                en_token[token] = 1
        
#print(sentence_length)
fig = plt.figure(figsize=(15,4))
ax1 = fig.add_subplot(1,2,1)
# ax1.scatter(sentence_length['len_fr'],sentence_length['len_en'],s=10,alpha=0.5,marker='o')
fr_x = np.asarray(sentence_length['len_fr'])
en_y = np.asarray(sentence_length['len_en'])
ax1 = sns.regplot(x=fr_x, y=en_y,color="g",fit_reg=True,scatter=True,label='length correaltion')
ax1.plot([0,300],[0,300],color='blue',label='y=x')
ax1.legend()
ax1.set_title('Sentence length correlation')
ax1.set_xlabel('Japanese')
ax1.set_ylabel('English')
#ax2 = fig.add_subplot(1,3,2)
# ax2.hist(sentence_length['len_fr'],bins=50)
#ax2 = sns.distplot(fr_x,bins=30,color='g')
#ax2.set_title('Sentence length distribution of Japanese')
#ax2.set_xlabel('Length')
#ax2.set_ylabel('Number')
ax3 = fig.add_subplot(1,2,2)
# ax3.hist(sentence_length['len_en'],bins=50)
sns.distplot(en_y,bins=30,color='g',label='English')
sns.distplot(fr_x,bins=30,color='b',label='Japanese')
ax3.legend()
ax3.set_title('Sentence length distribution of English and Japanese')
ax3.set_xlabel('Length')
ax3.set_ylabel('Distribution')
plt.show()

fig.savefig('distribution_plot.png', format="png")

# %%
en_sum = 0
fr_sum = 0
for item in en_token:
    en_sum += en_token[item]
for item in fr_token:
    fr_sum += fr_token[item]
print("Word tokens in English: {0}".format(en_sum))
print("Word tokens in Japanese: {0}".format(fr_sum))

print("Words type in English: {0}".format(len(en_token)))
print("Words type in Japanese: {0}".format(len(fr_token)))
#print(en_token)

unk_token_en = 0
unk_token_fr = 0

for item in en_token:
    if en_token[item] == 1: unk_token_en += 1
for item in fr_token:
    if fr_token[item] == 1: unk_token_fr += 1

print("Unknown token in English: {0}".format(unk_token_en))
print("Unknown token in Japanese: {0}".format(unk_token_fr))
# Out:
# Word tokens in English: 459895
# Word tokens in Japanese: 222757
# Words type in English: 9996
# Words type in Japanese: 72734
# Unknown token in English: 3552
# Unknown token in Japanese: 59254

# %%
#---------------------------------------------------------------------
# Set up model
#---------------------------------------------------------------------
model = EncoderDecoder(vocab_size_fr, vocab_size_en,
                       num_layers_enc, num_layers_dec,
                       hidden_units, gpuid, attn=use_attn)
if gpuid >= 0:
    cuda.get_device(gpuid).use()
    model.to_gpu()

optimizer = optimizers.Adam()
optimizer.setup(model)

'''
___QUESTION-1-DESCRIBE-F-START___

- Describe what the following line of code does
'''
optimizer.add_hook(chainer.optimizer.GradientClipping(threshold=5))
'''___QUESTION-1-DESCRIBE-F-END___'''
# Out:
# '___QUESTION-1-DESCRIBE-F-END___'

# %%
#---------------------------------------------------------------------
print("Training progress will be logged in:\n\t{0:s}".format(log_train_fil_name))
print("{0:s}".format("-"*50))
print("Trained model will be saved as:\n\t{0:s}".format(model_fil))
print("{0:s}".format("-"*50))
#---------------------------------------------------------------------
# Out:
# Training progress will be logged in:
# 	model/train_10000sen_1-1layers_100units_ja_en_exp2_SOFT_ATTN.log
# --------------------------------------------------
# Trained model will be saved as:
# 	model/seq2seq_10000sen_1-1layers_100units_ja_en_exp2_SOFT_ATTN.model
# --------------------------------------------------

# %%
#---------------------------------------------------------------------
# Evaluation utilities
#---------------------------------------------------------------------
# Compute perplexity over validation set
def compute_dev_pplx():
    loss = 0
    num_words = 0
    num_sents = 0
    with open(text_fname["fr"], "rb") as fr_file, open(text_fname["en"], "rb") as en_file:
        with tqdm(total=NUM_DEV_SENTENCES) as pbar:
            sys.stderr.flush()
            out_str = "loss={0:.6f}".format(0)
            pbar.set_description(out_str)
            for i, (line_fr, line_en) in enumerate(zip(fr_file, en_file), start=1):
                if i > NUM_TRAINING_SENTENCES and i <= (NUM_TRAINING_SENTENCES + NUM_DEV_SENTENCES):
                    fr_sent = line_fr.strip().split()
                    en_sent = line_en.strip().split()

                    fr_ids = [w2i["fr"].get(w, UNK_ID) for w in fr_sent]
                    en_ids = [w2i["en"].get(w, UNK_ID) for w in en_sent]

                    # compute loss
                    curr_loss = float(model.encode_decode_train(fr_ids, en_ids, train=False).data)  / len(en_ids)
                    loss += curr_loss
                    num_words += len(en_ids)

                    out_str = "loss={0:.6f}".format(curr_loss)
                    pbar.set_description(out_str)
                    pbar.update(1)
                    num_sents += 1
                
            # end for
        # end pbar
    # end with open file
    #loss_per_word = loss / num_words
    loss_per_sentence = loss / num_sents
    pplx = 2 ** loss_per_sentence

    print("{0:s}".format("-"*50))
    print("{0:14s} | {1:.4f}".format("dev perplexity", pplx))
    print("{0:14s} | {1:d}".format("# words in dev", num_words))
    print("{0:s}".format("-"*50))

    return pplx

# %%
#---------------------------------------------------------------------
# Compute Bleu score
#---------------------------------------------------------------------
def bleu_stats(hypothesis, reference):
    yield len(hypothesis)
    yield len(reference)
    for n in range(1,5):
        s_ngrams = Counter([tuple(hypothesis[i:i+n]) for i in range(len(hypothesis)+1-n)])
        r_ngrams = Counter([tuple(reference[i:i+n]) for i in range(len(reference)+1-n)])
        yield max([sum((s_ngrams & r_ngrams).values()), 0])
        yield max([len(hypothesis)+1-n, 0])

# Compute BLEU from collected statistics obtained by call(s) to bleu_stats
def bleu(stats):
    if len(list(filter(lambda x: x==0, stats))) > 0:
        return 0
    (c, r) = stats[:2]
    log_bleu_prec = sum([math.log(float(x)/y) for x,y in zip(stats[2::2],stats[3::2])]) / 4.
    return math.exp(min([0, 1-float(r)/c]) + log_bleu_prec)

def compute_dev_bleu():
    list_of_references = []
    list_of_hypotheses = []
    with open(text_fname["fr"], "rb") as fr_file, open(text_fname["en"], "rb") as en_file:
        for i, (line_fr, line_en) in enumerate(zip(fr_file, en_file), start=1):
            if i > NUM_TRAINING_SENTENCES and i <= (NUM_TRAINING_SENTENCES + NUM_DEV_SENTENCES):
                fr_sent = line_fr.strip().split()
                en_sent = line_en.strip().split()

                fr_ids = [w2i["fr"].get(w, UNK_ID) for w in fr_sent]
                en_ids = [w2i["en"].get(w, UNK_ID) for w in en_sent]

                list_of_references.append(line_en.strip().decode())
                pred_sent, alpha_arr = model.encode_decode_predict(fr_ids, max_predict_len=MAX_PREDICT_LEN)
                pred_words = [i2w["en"][w].decode() for w in pred_sent if w != EOS_ID]
                pred_sent_line = " ".join(pred_words)
                list_of_hypotheses.append(pred_sent_line)
            if i > (NUM_TRAINING_SENTENCES + NUM_DEV_SENTENCES):
                break

    stats = [0 for i in range(10)]
    for (r,h) in zip(list_of_references, list_of_hypotheses):
        stats = [sum(scores) for scores in zip(stats, bleu_stats(h,r))]

    bleu_score = (100 * bleu(stats))
    print("BLEU: {0:0.3f}".format(bleu_score))
    return bleu_score

# %%
#---------------------------------------------------------------------
# Main training loop
#---------------------------------------------------------------------
def train_loop(text_fname, num_training, num_epochs, log_mode="a"):
    # Set up log file for loss
    log_train_fil = open(log_train_fil_name, mode=log_mode)
    log_train_csv = csv.writer(log_train_fil, lineterminator="\n")

    sys.stderr.flush()

    for epoch in range(num_epochs):
        with open(text_fname["fr"], "rb") as fr_file, open(text_fname["en"], "rb") as en_file:
            with tqdm(total=num_training) as pbar:
                sys.stderr.flush()
                loss_per_epoch = 0
                out_str = "epoch={0:d}, iter={1:d}, loss={2:.6f}, mean loss={3:.6f}".format(
                                epoch+1, 0, 0, 0)
                pbar.set_description(out_str)

                for i, (line_fr, line_en) in enumerate(zip(fr_file, en_file), start=1):
                    fr_sent = line_fr.strip().split()
                    en_sent = line_en.strip().split()

                    fr_ids = [w2i["fr"].get(w, UNK_ID) for w in fr_sent]
                    en_ids = [w2i["en"].get(w, UNK_ID) for w in en_sent]

                    it = (epoch * NUM_TRAINING_SENTENCES) + i

                    if i > num_training:
                        break

                    # compute loss
                    loss = model.encode_decode_train(fr_ids, en_ids)

                    # clear gradient
                    model.cleargrads()
                    # backprop
                    loss.backward()
                    # update parameters
                    optimizer.update()
                    # store loss value for display
                    loss_val = float(loss.data) / len(en_ids)
                    loss_per_epoch += loss_val

                    out_str = "epoch={0:d}, iter={1:d}, loss={2:.6f}, mean loss={3:.6f}".format(
                               epoch+1, it, loss_val, (loss_per_epoch / i))
                    pbar.set_description(out_str)
                    pbar.update(1)

                    # log every 100 sentences
                    if i % 100 == 0:
                        log_train_csv.writerow([it, loss_val])


        # compute precision, recall and F-score
        metrics = predict(s=NUM_TRAINING_SENTENCES, 
                         num=NUM_DEV_SENTENCES, display=False, plot=False)
        prec = np.sum(metrics["cp"]) / np.sum(metrics["tp"])
        rec = np.sum(metrics["cp"]) / np.sum(metrics["t"])
        f_score = 2 * (prec * rec) / (prec + rec)

        print("{0:s}".format("-"*50))
        print("{0:10s} | {1:0.4f}".format("precision", prec))
        print("{0:10s} | {1:0.4f}".format("recall", rec))
        print("{0:10s} | {1:0.4f}".format("f1", f_score))
        print("{0:s}".format("-"*50))
        print("computing perplexity")
        pplx = compute_dev_pplx()

        # Backup model every epoch
        print("Saving model")
        serializers.save_npz(model_fil, model)
        print("Finished saving model")
        print("{0:s}".format("-"*50))

        # Compute Bleu every 2 epochs
        if epoch % 2 == 0:
            print("computing bleu")
            bleu_score = compute_dev_bleu()
            print("finished computing bleu ... ")
            print("{0:s}".format("-"*50))
        
    # At the end of training, make some predictions
    # make predictions over both training and dev sets
    print("Training set predictions")
    _ = predict(s=0, num=3, plot=False)
    print("{0:s}".format("-"*50))
    print("dev set predictions")
    _ = predict(s=NUM_TRAINING_SENTENCES, num=3, plot=False)
    print("{0:s}".format("-"*50))

    print("{0:s}".format("-"*50))
    # Check if Bleu needs to be recomputed
    if num_epochs % 2 != 0:
        bleu_score = compute_dev_bleu()
        print("{0:s}".format("-"*50))
    print("{0:s}".format("-"*50))

    # close log file
    log_train_fil.close()
    print("Finished training. Filenames:")
    print(log_train_fil_name)
    print(model_fil)

# %%
#---------------------------------------------------------------------
# __QUESTION -- Following code is to assist with ATTENTION
#---------------------------------------------------------------------
from matplotlib.font_manager import FontProperties
'''
Support function to plot attention vectors
'''
def plot_attention(alpha_arr, fr, en, plot_name=None):
    print(alpha_arr.shape)
    if gpuid >= 0:
        alpha_arr = cuda.to_cpu(alpha_arr).astype(np.float32)

    #alpha_arr /= np.max(np.abs(alpha_arr),axis=0)
    fig = plt.figure()
    fig.set_size_inches(8, 8)

    gs = gridspec.GridSpec(2, 2, width_ratios=[12,1],height_ratios=[12,1])

    ax = plt.subplot(gs[0])
    ax_c = plt.subplot(gs[1])

    cmap = sns.light_palette((200, 75, 60), input="husl", as_cmap=True)
    prop = FontProperties(fname='fonts/IPAfont00303/ipam.ttf', size=12)
    ax = sns.heatmap(alpha_arr, xticklabels=fr, yticklabels=en, ax=ax, cmap=cmap, cbar_ax=ax_c)

    ax.xaxis.tick_top()
    ax.yaxis.tick_right()

    ax.set_xticklabels(en, minor=True, rotation=60, size=12)
    for label in ax.get_xticklabels(minor=False):
        label.set_fontsize(12)
        label.set_font_properties(prop)

    for label in ax.get_yticklabels(minor=False):
        label.set_fontsize(12)
        label.set_rotation(-90)
        label.set_horizontalalignment('left')

    ax.set_xlabel("Source", size=20)
    ax.set_ylabel("Hypothesis", size=20)

    if plot_name:
        fig.savefig(plot_name, format="png")

# %%
#---------------------------------------------------------------------
# Helper function for prediction
#---------------------------------------------------------------------
def predict_sentence(line_fr, line_en=None, display=True, 
                     plot_name=None, p_filt=0, r_filt=0, sample=False):
    fr_sent = line_fr.strip().split()
    fr_ids = [w2i["fr"].get(w, UNK_ID) for w in fr_sent]
    # english reference is optional. If provided, compute precision/recall
    if line_en:
        en_sent = line_en.strip().split()
        en_ids = [w2i["en"].get(w, UNK_ID) for w in en_sent]

    pred_ids, alpha_arr = model.encode_decode_predict(fr_ids, 
                                                      max_predict_len=MAX_PREDICT_LEN,
                                                      sample=sample)
    pred_words = [i2w["en"][w].decode() for w in pred_ids]

    prec = 0
    rec = 0
    filter_match = False

    matches = count_match(en_ids, pred_ids)
    prec = matches/len(pred_ids)
    rec = matches/len(en_ids)

    if display and (prec >= p_filt and rec >= r_filt):
        filter_match = True
        # convert raw binary into string
        fr_words = [w.decode() for w in fr_sent]

        print("{0:s}".format("-"*50))
        print("{0:s} | {1:80s}".format("Src", line_fr.strip().decode()))
        print("{0:s} | {1:80s}".format("Ref", line_en.strip().decode()))
        print("{0:s} | {1:80s}".format("Hyp", " ".join(pred_words)))

        print("{0:s}".format("-"*50))

        print("{0:s} | {1:0.4f}".format("precision", prec))
        print("{0:s} | {1:0.4f}".format("recall", rec))

        if plot_name and use_attn:
            plot_attention(alpha_arr, fr_words, pred_words, plot_name)

    return matches, len(pred_ids), len(en_ids), filter_match

# %%
#---------------------------------------------------------------------
'''
Function to make predictions.
s       : starting index of the line in the parallel data from which to make predictions
num     : number of lines starting from "s" to make predictions for
plot    : plot attention if True
display : whether to display additional info
p_filt  : precision filter. Only displays predicted sentences with precision above p_filt
r_filt  : recall filter. Only displays predicted sentences with recall above p_filt
sample  : if False, predict word with maximum probability in the model, else sample
'''
#---------------------------------------------------------------------
def predict(s=NUM_TRAINING_SENTENCES, num=NUM_DEV_SENTENCES, 
            display=True, plot=False, p_filt=0, r_filt=0, sample=False):
    
    if display:
        print("English predictions, s={0:d}, num={1:d}:".format(s, num))

    metrics = {"cp":[], "tp":[], "t":[]}

    filter_count = 0

    with open(text_fname["fr"], "rb") as fr_file, open(text_fname["en"], "rb") as en_file:
        for i, (line_fr, line_en) in enumerate(zip(fr_file, en_file), start=0):
            if i >= s and i < (s+num):
                if plot:
                    plot_name = os.path.join(model_dir, "sample_{0:d}_plot.png".format(i+1))
                else:
                    plot_name=None

                # make prediction
                cp, tp, t, f = predict_sentence(line_fr,
                                             line_en,
                                             display=display,
                                             plot_name=plot_name, 
                                             p_filt=p_filt, r_filt=r_filt,
                                             sample=sample)
                metrics["cp"].append(cp)
                metrics["tp"].append(tp)
                metrics["t"].append(t)
                filter_count += (1 if f else 0)

    if display:
        print("sentences matching filter = {0:d}".format(filter_count))
    
    return metrics

# %%
#---------------------------------------------------------------------
# Helper function to compute precision recall
#---------------------------------------------------------------------
def count_match(list1, list2):
    # each list can have repeated elements. The count should account for this.
    count1 = Counter(list1)
    count2 = Counter(list2)
    count2_keys = count2.keys()-set([UNK_ID])
    common_w = set(count1.keys()) & set(count2_keys)
    matches = sum([min(count1[w], count2[w]) for w in common_w])
    return matches

# %%
#---------------------------------------------------------------------
# Main -- program execution starts here
#---------------------------------------------------------------------

def main():
    print("Existing model {0:s}".format("found" if os.path.exists(model_fil) else "not found!"))
    print("{0:s}".format("-"*50))
    if os.path.exists(model_fil):
        if load_existing_model:
            print("loading model ...")
            serializers.load_npz(model_fil, model)
            print("finished loading: {0:s}".format(model_fil))
            print("{0:s}".format("-"*50))
        else:
            print("""model file already exists!!
                Delete before continuing, or enable load_existing flag""".format(model_fil))
            return

    if NUM_EPOCHS > 0:
        train_loop(text_fname, NUM_TRAINING_SENTENCES, NUM_EPOCHS)
    
if __name__ == "__main__":
    main()

#---------------------------------------------------------------------

def test_lam_tran():
    lines_fr = ["君 は １ 日 で それ が でき ま す か 。", "皮肉 な 笑い を 浮かべ て 彼 は 私 を 見つめ た 。", "あなた は 午後 何 を し た い で す か 。"]
    lines_en = ["can you do it in one day ?", "he stared at me with a satirical smile .", "what do you want to do in the afternoon ?" ]

    for line_fr, line_en in zip(lines_fr, lines_en):
        line_fr = line_fr.encode()
        line_en = line_en.encode()

        predict_sentence(line_fr=line_fr, line_en=line_en)
# Out:
# Existing model found
# --------------------------------------------------
# loading model ...
# finished loading: model/seq2seq_10000sen_1-1layers_100units_ja_en_exp2_SOFT_ATTN.model
# --------------------------------------------------

# %%
_ = predict(s=NUM_TRAINING_SENTENCES,num=NUM_DEV_SENTENCES)
# Out:
# English predictions, s=10000, num=500:
# --------------------------------------------------
# Src | この 路地 は 通り抜け でき ま せ ん 。
# Ref | this is a dead @-@ end alley .
# Hyp | i can &apos;t come can can . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1250
# --------------------------------------------------
# Src | ええ 、 届 い た の を お 知 らせ する の を 忘れ て しま っ て す み ま せ ん 。
# Ref | yes , sorry , i forgot to acknowledge it .
# Hyp | i &apos;m to forget to forget the to the the the the you the . . _EOS
# --------------------------------------------------
# precision | 0.1765
# recall | 0.3000
# --------------------------------------------------
# Src | 彼 は ドイツ 生まれ の 人 だ 。
# Ref | he is a german by origin .
# Hyp | he is born two two . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.4286
# --------------------------------------------------
# Src | 我々 は ロビン フッド の 伝説 を 良く 知 っ て い る 。
# Ref | we are familiar with the legend of robin hood .
# Hyp | we have as to all the _UNK . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3000
# --------------------------------------------------
# Src | トランク に は 鍵 が かけ られ て い ま す か 。
# Ref | is your trunk locked ?
# Hyp | is there going _UNK in _UNK ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.4000
# --------------------------------------------------
# Src | それ は 冗談 の つもり で い っ た だけ だ よ 。
# Ref | i just meant it as a joke .
# Hyp | that &apos;s the as as as as joke . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3750
# --------------------------------------------------
# Src | その 部屋 は 居心地 の 良 い 感じ が し た 。
# Ref | the room had a nice cozy feel .
# Hyp | the boy was dry in awkward . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | パソコン が 使え る の は 彼女 だけ で す 。
# Ref | she alone is able to use the personal computer .
# Hyp | she is ready to as master to . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4000
# --------------------------------------------------
# Src | 彼 ら は 共同 声明 に 同意 し た 。
# Ref | they agreed on a joint statement .
# Hyp | they satisfied on the with . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 彼 は 彼女 を バス に 助け あげ た 。
# Ref | he handed her up into the bus .
# Hyp | he help me for for help . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | 彼 に どんな 欠点 が あ る に し て も 、 卑劣 な ところ は な い 。
# Ref | whatever faults he may have , meanness is not one of them .
# Hyp | no can &apos;t no no that that that that that that . . . _EOS
# --------------------------------------------------
# precision | 0.0667
# recall | 0.0769
# --------------------------------------------------
# Src | 「 こんな 朝 早く から 開館 し て る ん で す か ？ 」 「 私 は 顔 パス よ 」
# Ref | &quot; will they be open this early in the morning ? &quot; &quot; they &apos;ll let me in on sight . &quot;
# Hyp | &quot; &apos;s _UNK &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; &quot; ? &quot; &quot; &quot; &quot;
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2273
# --------------------------------------------------
# Src | 人間 も 極度 に 寒 い 温度 に 対 し て は 、 防御 装置 を 備え て い る 。
# Ref | man , too , has been given protective devices against extreme temperatures .
# Hyp | no is live for in in in in in in in in in . . _EOS
# --------------------------------------------------
# precision | 0.0625
# recall | 0.0769
# --------------------------------------------------
# Src | 私 は タバコ を 吸 う の を やめ た 。
# Ref | i stopped smoking .
# Hyp | i got my smoking . . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.7500
# --------------------------------------------------
# Src | 彼 は かっと な っ て 私 を 殴 っ た 。
# Ref | he struck me in a passion .
# Hyp | he took an _UNK my _UNK . . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2857
# --------------------------------------------------
# Src | 彼 は ロープ を 引っ張 っ た 。
# Ref | he pulled the rope .
# Hyp | he took the the . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.6000
# --------------------------------------------------
# Src | どう し て あやま っ て 彼 の 許し を こ わ な い ん だ 。
# Ref | why not apologize and ask for his pardon ?
# Hyp | i don &apos;t _UNK his his his his his his . _EOS
# --------------------------------------------------
# precision | 0.0833
# recall | 0.1111
# --------------------------------------------------
# Src | 私 は 彼 ら は 来る と 思 う 。
# Ref | i suppose they are coming .
# Hyp | i will all come away . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 丘 の 上 に 建 っ て い る 家 は とても 古 い 。
# Ref | the house which stands on the hill is very old .
# Hyp | all hill hard to very very very very very . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.2727
# --------------------------------------------------
# Src | 私 は 早 く 着 き すぎ た 。
# Ref | i arrived there too early .
# Hyp | i finished to my . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | 私 は 彼 の 親切 に こたえ た い 。
# Ref | i would like to repay him for his kindness .
# Hyp | i love kind to kind . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3000
# --------------------------------------------------
# Src | 屋根 は 強風 に 飛ば さ れ た 。
# Ref | the roof was torn off by the gale .
# Hyp | the _UNK was heated _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3333
# --------------------------------------------------
# Src | 霧 の 中 から 突然 船 が 現れ た 。
# Ref | a boat suddenly appeared out of the mist .
# Hyp | all were all all all all all . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1111
# --------------------------------------------------
# Src | 車 が 衝突 し た とき シート ベルト を し て い た ら 、 彼 は 今 で も 生き て い る だ ろ う 。
# Ref | he would still be alive if he had been wearing his seat belt when the car crashed .
# Hyp | when he would that he , he he he he he he he he not he . . _EOS
# --------------------------------------------------
# precision | 0.2632
# recall | 0.2778
# --------------------------------------------------
# Src | あなた が 結婚 し 子供 を 持 っ た ら 、 言葉 より 実践 と い う こと を 悟 る で しょ う 。
# Ref | when you get married and have kids , you &apos;ll realize that actions speak louder than words .
# Hyp | you will take _UNK _UNK that of of that of _UNK . . _EOS
# --------------------------------------------------
# precision | 0.2143
# recall | 0.1667
# --------------------------------------------------
# Src | それ は 遺憾 な ところ が 多 い 。
# Ref | it leaves nothing much to be desired .
# Hyp | it &apos;s a in _UNK . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2500
# --------------------------------------------------
# Src | その 装置 が 作動 し て い る 間 は 暖房 を 止め る こと は でき な い 。
# Ref | you can &apos;t turn the heat off as long as the system is operating .
# Hyp | there &apos;s _UNK _UNK _UNK _UNK _UNK in this this this this . . . _EOS
# --------------------------------------------------
# precision | 0.0625
# recall | 0.0667
# --------------------------------------------------
# Src | ピクニック は 雨 の ため に 中止 に な っ た 。
# Ref | the picnic was called off because of rain .
# Hyp | the earth _UNK to we the the rain . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は 週末 に よく 家 を 空け る 。
# Ref | he often stays away from home on the weekend .
# Hyp | he often often home on house on . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5000
# --------------------------------------------------
# Src | その シェパード は 、 びっこ を ひ き ながら 道 を 歩 い て い た 。
# Ref | the german shepherd was limping down the street .
# Hyp | the _UNK was a a a a a . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3333
# --------------------------------------------------
# Src | ボブ は 読 み きれ な い ほど たくさん の 本 を 持 っ て い る 。
# Ref | bob has too many books to read .
# Hyp | bob is books books books books books books books . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3750
# --------------------------------------------------
# Src | 板 に くぎ を 打ち込 ん だ 。
# Ref | he hammered nails into the plank .
# Hyp | i _UNK a _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1429
# --------------------------------------------------
# Src | 宿題 は もう 終わ っ た の で す か 。
# Ref | have you finished your homework already ?
# Hyp | how long have homework homework homework ? _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | まず その 辺 で す 。
# Ref | that &apos;s about it .
# Hyp | the _UNK is that _UNK _UNK _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.2000
# --------------------------------------------------
# Src | 夢 は 、 世界 一周 旅行 。
# Ref | my dream is to take a round @-@ the @-@ world trip .
# Hyp | how is a after stretch . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.2308
# --------------------------------------------------
# Src | 今夜 は 家 に つれ て い っ て く れ 。
# Ref | please take me home tonight .
# Hyp | the is he get he the . . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1667
# --------------------------------------------------
# Src | ２ 日間 ベッド に い な く て は な ら な かっ た 。
# Ref | i have had to stay in bed for two days .
# Hyp | you had no to _UNK to _UNK . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.2727
# --------------------------------------------------
# Src | 消防 士 は あっ と い う 間 に 火 を 消 し た 。
# Ref | the firemen had the fire out in no time .
# Hyp | _UNK _UNK _UNK _UNK _UNK the the the . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3000
# --------------------------------------------------
# Src | あなた の 傘 を 借り て い い で す か 。
# Ref | can i borrow your umbrella ?
# Hyp | may i keep you your window ? _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | 明日 雨降り なら 私 は 家 に い ま す 。
# Ref | i will stay home if it rains tomorrow .
# Hyp | it cloudy at at at home . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3333
# --------------------------------------------------
# Src | 彼女 が 最後 に ゴール し た 人 で す 。
# Ref | she was the last to cross the finishing line .
# Hyp | she is a hope _UNK . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2000
# --------------------------------------------------
# Src | 写真 ほど 鮮明 な もの は な い 。
# Ref | nothing is more vivid than a picture .
# Hyp | excuse as far as as as important . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1250
# --------------------------------------------------
# Src | 減税 は しばしば 経済 を 刺激 する 重要 な 財政 政策 手段 と し て 使 わ れ る 。
# Ref | tax cuts are often used as a major fiscal tool to stimulate the economy .
# Hyp | _UNK _UNK make to to to making making a making _UNK . _EOS
# --------------------------------------------------
# precision | 0.2308
# recall | 0.2000
# --------------------------------------------------
# Src | 橋 が 圧力 で 落ち た 。
# Ref | the bridge crashed under the pressure .
# Hyp | the bill _UNK _UNK in . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 私 は その 事実 を 十分 よく 知 っ て い る 。
# Ref | i know the facts well enough .
# Hyp | i know the the the in the fact . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.5714
# --------------------------------------------------
# Src | 彼 の 後 を 継 ぐ だけ の 能力 の あ る 人物 を 見つけ る の は 容易 で は な い だ ろ う 。
# Ref | it won &apos;t be easy to find someone capable of taking his place .
# Hyp | he can no to be the who who who who who who who who the . _EOS
# --------------------------------------------------
# precision | 0.1765
# recall | 0.2143
# --------------------------------------------------
# Src | 私 は 一 番 列車 に 間に合 う よう に 急 い だ 。
# Ref | i hurried in order to catch the first train .
# Hyp | i have hurry to be be be time time . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3000
# --------------------------------------------------
# Src | 私 は もはや 彼 の なまけ を 我慢 出来 な い 。
# Ref | i cannot put up with his idleness any longer .
# Hyp | i can &apos;t as his as . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3000
# --------------------------------------------------
# Src | 彼女 は 叔母 に 似 て い る 。
# Ref | she resembles her aunt .
# Hyp | she is aunt to my . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.6000
# --------------------------------------------------
# Src | 彼 は い い 給料 を もら っ て い る 。
# Ref | he earns a good salary .
# Hyp | he has a taken a . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.5000
# --------------------------------------------------
# Src | 歌 を 歌 っ て い る 少年 は 私 の 弟 で す 。
# Ref | the boy singing a song is my brother .
# Hyp | it &apos;s to to to &apos;s to songs . . _EOS
# --------------------------------------------------
# precision | 0.0909
# recall | 0.1111
# --------------------------------------------------
# Src | 彼女 は ベッド の 上 に うつ伏せ に 倒れ て い た 。
# Ref | she was lying face down on the bed .
# Hyp | she was _UNK on on in . . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4444
# --------------------------------------------------
# Src | 急 い で する 事 が あ る 。
# Ref | i have an urgent matter to attend to .
# Hyp | it can make to _UNK . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2222
# --------------------------------------------------
# Src | 私 は 、 ストライキ の ため に 、 旅行 を 中止 し な けれ ば な ら な かっ た 。
# Ref | i had to cancel my trip on account of the strike .
# Hyp | i had to _UNK for for we . . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.3333
# --------------------------------------------------
# Src | だれ で も が み な 正直 と は 限 ら な い 。
# Ref | everyone is not honest .
# Hyp | not may not like in in . . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.4000
# --------------------------------------------------
# Src | もし 私 が 君 の 立場 なら 、 彼 を 手伝 っ て や る だ ろ う に 。
# Ref | if i were in your place , i would lend him a hand .
# Hyp | i &apos;m i you you you i i you . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2143
# --------------------------------------------------
# Src | 早起き の 習慣 を 養 う よう に し なさ い 。
# Ref | you should cultivate the habit of getting up early .
# Hyp | bring your my to expect change my . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1000
# --------------------------------------------------
# Src | 君 に 会 っ た こと を 私 は 決して 忘れ ま せ ん 。
# Ref | i will never forget seeing you .
# Hyp | i never never back my that i long . . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.4286
# --------------------------------------------------
# Src | カナダ へ 行 っ た こと が あ り ま す か 。
# Ref | have you ever been to canada ?
# Hyp | i you ever been you ? _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.5714
# --------------------------------------------------
# Src | バス の 前 の ほう は す い て い た 。
# Ref | the front of the bus was not crowded .
# Hyp | there were said at the . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2222
# --------------------------------------------------
# Src | 彼 は 出かけ た 先々 で 歓迎 さ れ た 。
# Ref | he was welcomed wherever he went .
# Hyp | he was _UNK by by by . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.4286
# --------------------------------------------------
# Src | 彼 は 自分 が 何 を 話 し て い る か を 時々 忘れ て しま う 。
# Ref | he sometimes forgets what he was talking about .
# Hyp | how has he he he he he _UNK _UNK _UNK _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2222
# --------------------------------------------------
# Src | 彼女 は その 仕事 を する 気分 で は な い 。
# Ref | she is in no humor for task .
# Hyp | she is no to do . . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5000
# --------------------------------------------------
# Src | 私 は 野球 が 好き だ 。
# Ref | i like baseball .
# Hyp | i like fond class baseball . _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 1.0000
# --------------------------------------------------
# Src | その 名 の 人 は 学籍 簿 に 載 っ て ま せ ん 。
# Ref | no person by that name is listed in the register of the school .
# Hyp | the is is no use front at the . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.3571
# --------------------------------------------------
# Src | 収穫 が もっと 悪 く な れ ば 、 飢饉 が 起こ る か も 知れ な い 。
# Ref | if the harvest gets any worse , there could be a famine .
# Hyp | i can &apos;t get she meet she meet will meet . . _EOS
# --------------------------------------------------
# precision | 0.0769
# recall | 0.0769
# --------------------------------------------------
# Src | 父 は 私 が 彼 に 対 し て 失礼 な 言動 を と っ た とき 、 怒り で 顔 が 真っ赤 に な っ た 。
# Ref | father went red with anger when i behaved rudely towards him .
# Hyp | my father was him him and , him his him _UNK him _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1875
# recall | 0.2500
# --------------------------------------------------
# Src | 彼 は 山 の 頂上 に 立 っ て い ま し た 。
# Ref | he was standing at the top of the mountain .
# Hyp | he was over the the the . . _EOS
# --------------------------------------------------
# precision | 0.5556
# recall | 0.5000
# --------------------------------------------------
# Src | 私 たち みんな 自転 車 に 乗 る の が 好き で す 。
# Ref | we all like cycling .
# Hyp | we like no a with fond . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.6000
# --------------------------------------------------
# Src | 赤ん坊 は よく 転 ぶ 。
# Ref | babies often fall down .
# Hyp | the baby often well . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | その 質問 は 難し すぎ て 答え られ な かっ た 。
# Ref | the question was too difficult to answer .
# Hyp | the _UNK was too too too too . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.5000
# --------------------------------------------------
# Src | 彼女 は 教師 の よう に 見え る 。
# Ref | she looks like a teacher .
# Hyp | she looks like a horse . _EOS
# --------------------------------------------------
# precision | 0.7143
# recall | 0.8333
# --------------------------------------------------
# Src | ジョーダン さん は 「 授業 に 出 て い な かっ た の で す か 」 と たずね た 。
# Ref | &quot; weren &apos;t you there ? &quot; asked mr jordan .
# Hyp | _UNK had to you to you had you had ? ? _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.1818
# --------------------------------------------------
# Src | 「 ほか に 何 か 要 り ま す か 」 「 それ だけ で 結構 で す 」
# Ref | &quot; anything else ? &quot; &quot; no , that &apos;s all . &quot;
# Hyp | &quot; why you the &quot; ? &quot; ? &quot; ? &quot; ? &quot; ? _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.3846
# --------------------------------------------------
# Src | 気 苦労 が 彼 の 体 に 響 い た 。
# Ref | worry affected his health .
# Hyp | the _UNK famous animated his his death . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.4000
# --------------------------------------------------
# Src | 彼 は それ を 詳し く 説明 し だ し た 。
# Ref | he explained it at length .
# Hyp | he _UNK a _UNK the it . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | 「 元気 を 出 し なさ い 」 と 彼女 は 私 に 言 い ま し た 。
# Ref | &quot; cheer up , &quot; she said to me .
# Hyp | &quot; &apos;m all you better you you you . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2000
# --------------------------------------------------
# Src | 本当 を 言 う と 、 コンピューター に は 詳し く な い の で す 。
# Ref | i &apos;m not really familiar with computers .
# Hyp | the fact , the is , in is is in . . _EOS
# --------------------------------------------------
# precision | 0.0769
# recall | 0.1250
# --------------------------------------------------
# Src | ワイン を もっと 冷や し た い 。
# Ref | i want to chill the wine more .
# Hyp | please help yourself to your _UNK . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2500
# --------------------------------------------------
# Src | 彼女 は 機嫌 が 悪 い と い う の も 、 いつ も 地下 鉄 に 乗 り 遅れ 仕事 場 まで 歩 く 羽目 に な っ た から だ 。
# Ref | she is in a temper , because she missed her usual train in the subway and had to walk to work .
# Hyp | if she was that that that that , had that had had had had had had had had the .
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2273
# --------------------------------------------------
# Src | 夕方 から 雨 だ って い っ て い た よ 。
# Ref | it said rain from this evening .
# Hyp | i &apos;ve had it down it down . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2857
# --------------------------------------------------
# Src | あす の 朝 まで に は 一面 の 銀 世界 に な っ て い る だ ろ う 。
# Ref | by tomorrow morning all the world will have been covered with snow .
# Hyp | it will get that the the the the the the the . . _EOS
# --------------------------------------------------
# precision | 0.2143
# recall | 0.2308
# --------------------------------------------------
# Src | 知 っ て い れ ば 教え て あげ た ん だ けど 。
# Ref | had i known it , i would have told you .
# Hyp | that you had been when when i _UNK . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.3636
# --------------------------------------------------
# Src | 無知 は 幸福 。
# Ref | ignorance is bliss .
# Hyp | the is always quickly . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.5000
# --------------------------------------------------
# Src | せっかく 弁護 士 の 資格 が あ る の に もったい な い 。
# Ref | what a waste of your lawyer qualifications !
# Hyp | i can &apos;t have to a the _UNK . . _EOS
# --------------------------------------------------
# precision | 0.0909
# recall | 0.1250
# --------------------------------------------------
# Src | 少な い 収入 を でき る 限り いか し た い 。
# Ref | make the best of your small income .
# Hyp | you can i that i i i i i you you . . . _EOS
# --------------------------------------------------
# precision | 0.0667
# recall | 0.1250
# --------------------------------------------------
# Src | いつ か あなた を 訪問 し て も い い で す か 。
# Ref | may i call on you some day ?
# Hyp | may i would you to you this ? ? _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.5000
# --------------------------------------------------
# Src | 私 は ここ に とどま る べ き か ロンドン へ 行 く べ き か 分か ら な かっ た 。
# Ref | i didn &apos;t know whether to stay here or go to london .
# Hyp | i had to go to go we go go go go to . _EOS
# --------------------------------------------------
# precision | 0.3571
# recall | 0.3846
# --------------------------------------------------
# Src | ダン は よく お 母 さん に しか ら れ る 。
# Ref | dan is often scolded by his mother .
# Hyp | the _UNK often go a go . . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2500
# --------------------------------------------------
# Src | ジョージ は とても 話 好き だ 。
# Ref | george is quite talkative .
# Hyp | george is very very very very _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | システム が 作動 し な い 場合 が あ る 。
# Ref | there are cases where the system doesn &apos;t go .
# Hyp | there is a _UNK _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2000
# --------------------------------------------------
# Src | 彼女 は 毎週 １ 回 映画 を 見 に 行 く 。
# Ref | she goes to the movies once a week .
# Hyp | she has a to a a a @-@ @-@ _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は とって も やさし い よ 。
# Ref | he is fine and gentle .
# Hyp | he is a a a . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | 私 は ほとんど １８０ センチ で す 。
# Ref | i am almost 180 centimeters tall .
# Hyp | i like my little and . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 彼 は 母親 に 似 て い る 。
# Ref | he resembles his mother .
# Hyp | he is tire to . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | 東京 は だんぜん 日本 で 一番 大き い 都市 で す 。
# Ref | tokyo is by far the largest city in japan .
# Hyp | tokyo is the japanese japanese japanese japanese . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4000
# --------------------------------------------------
# Src | 出世 し た い の なら 、 努力 を おそれ て は な ら な い 。
# Ref | if you wish to get on in the world , you must not shrink from effort .
# Hyp | i may effort to to you to to to to . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.2353
# --------------------------------------------------
# Src | 「 まだ 浅 い ね 。 足 とど く 」 「 結構 遠浅 だ な 。 よ つば も まだ 足 つ く だ ろ 」
# Ref | &quot; it &apos;s still shallow , eh . my feet still touch the bottom . &quot; &quot; it &apos;s quite a shallow beach . yotsuba , you can still touch the bottom can &apos;t you ? &quot;
# Hyp | &quot; _UNK isn ! _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK
# --------------------------------------------------
# precision | 0.0500
# recall | 0.0270
# --------------------------------------------------
# Src | 私 の お じい ちゃん は 私 が 大学 に 行 く こと を 望 ん で い る 。
# Ref | my grandfather hopes that i will enter college .
# Hyp | my my is always studying with . . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | ラスベガス が い る と 時間 が 経 つ の を 忘れ る 。
# Ref | it &apos;s easy to lose track of time when you are in las vegas .
# Hyp | i &apos;ll have my will my address will my . _EOS
# --------------------------------------------------
# precision | 0.0909
# recall | 0.0667
# --------------------------------------------------
# Src | 彼 は 非常 な 剣幕 で 私 を にらみ付け た 。
# Ref | he glared at me fiercely .
# Hyp | he got his by his . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 間 の 垣根 が 恋 を いっそう 燃え立 た せ る 。
# Ref | a fence between makes love more keen .
# Hyp | a _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.2500
# --------------------------------------------------
# Src | キャロライン は すべて の お 金 を 洋服 に 使 う ほど 愚か で は な い 。
# Ref | caroline knows better than to spend all her money on clothes .
# Hyp | _UNK _UNK not _UNK to at to at the _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.1538
# recall | 0.1667
# --------------------------------------------------
# Src | 彼 は 駐日 アメリカ 大使 に 命 じ られ た ばかり で す 。
# Ref | he has just been appointed the u.s. ambassador to japan .
# Hyp | he was just _UNK my year year year . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.2727
# --------------------------------------------------
# Src | 彼女 なら 当然 選 び そう な 人 と 彼女 は 結婚 し た 。
# Ref | she married to the kind of man you would expect her to pick .
# Hyp | she got she she she she she she was she she . . _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.1429
# --------------------------------------------------
# Src | 昨日 通り で 友人 に 会 っ た 。
# Ref | i met my friend on the street .
# Hyp | i got my trouble met met her met . _EOS
# --------------------------------------------------
# precision | 0.4000
# recall | 0.5000
# --------------------------------------------------
# Src | お 酒 を 飲 む と 影響 が 出 る もの だ 。
# Ref | liquor will have an effect on a person .
# Hyp | i &apos;m just get to a . . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | 君 を 信頼 し て い る 。
# Ref | i believe in you .
# Hyp | i &apos;m on with . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4000
# --------------------------------------------------
# Src | 我々 の 列車 は 時速 ２００ キロ で 走 っ た 。
# Ref | our train went at 200 kilometers an hour .
# Hyp | we train due _UNK the the the _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2222
# --------------------------------------------------
# Src | 私 たち は 泣 い て い る の 。
# Ref | we are crying .
# Hyp | we are all crying . _EOS
# --------------------------------------------------
# precision | 0.6667
# recall | 1.0000
# --------------------------------------------------
# Src | 彼女 は 息 を 飲 ん だ 。
# Ref | she caught her breath .
# Hyp | she drank a a a . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | 君 たち は 大人 に な る まで タバコ を 吸 っ て は いけ な い 。
# Ref | you must not smoke till you grow up .
# Hyp | you have not go from from far go . . _EOS
# --------------------------------------------------
# precision | 0.2727
# recall | 0.3333
# --------------------------------------------------
# Src | 彼 は たばこ を 一 日 一 本 に 減ら し て い っ た 。
# Ref | he tapered off to one cigarette a day .
# Hyp | he was his in the the the the . . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2222
# --------------------------------------------------
# Src | 貴殿 の 娘 さん は 麻薬 漬け で す 。
# Ref | your daughter &apos;s on drugs .
# Hyp | _UNK &apos;s mr _UNK mr run _UNK _UNK _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1667
# --------------------------------------------------
# Src | 彼女 を その 任務 に 就け よう 。
# Ref | let &apos;s put her in charge of that .
# Hyp | i will take the _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1111
# --------------------------------------------------
# Src | ある 旅行 会社 が 我々 の 旅行 の 手配 を 全部 し て くれ た 。
# Ref | a travel agent arranged everything for our trip .
# Hyp | a _UNK _UNK _UNK to our _UNK _UNK _UNK . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.3333
# --------------------------------------------------
# Src | 彼女 が 息子 を 自慢 する の も もっとも だ 。
# Ref | she may well be proud of her son .
# Hyp | she &apos;s ashamed to son son her . _EOS
# --------------------------------------------------
# precision | 0.4444
# recall | 0.4444
# --------------------------------------------------
# Src | 痛み が 右脚 に 走 り ま す 。
# Ref | the pain shoots into my right leg .
# Hyp | my _UNK _UNK run . . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2500
# --------------------------------------------------
# Src | 参加 者 の リスト は 次 の とおり で す 。
# Ref | the list of participants is as follows .
# Hyp | breakfast is no quarter as alone . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3750
# --------------------------------------------------
# Src | 彼女 は 休日 に な る と よく 買い物 に 行 き ま す 。
# Ref | she will often go shopping on holidays .
# Hyp | she often go to go to go go . . _EOS
# ...
# --------------------------------------------------
# Src | 少し 待 っ て くれ た ら 、 ジェーン を 電話 に 出 さ せ ま す 。
# Ref | if you hold on a moment , i will get jane on the phone .
# Hyp | you let you you if a if phone a the say . _EOS
# --------------------------------------------------
# precision | 0.4615
# recall | 0.4000
# --------------------------------------------------
# Src | 彼女 と は ときおり 美容 院 で 会 い ま す 。
# Ref | i meet her on occasion at a beauty shop .
# Hyp | she is past in in in in in her . _EOS
# --------------------------------------------------
# precision | 0.1818
# recall | 0.2000
# --------------------------------------------------
# Src | しかし 、 主人 公 は 自ら の 誤り に 気づ い て い る 。
# Ref | however the protagonist is aware of his own mistakes .
# Hyp | however of the _UNK the the the the partly name . . _EOS
# --------------------------------------------------
# precision | 0.3077
# recall | 0.4000
# --------------------------------------------------
# Src | 私 は 彼 の 態度 に 我慢 でき な い 。
# Ref | i cannot abide his manner .
# Hyp | i &apos;m not his his his his . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.5000
# --------------------------------------------------
# Src | 彼 は 何事 も 程々 と い う 事 を 知 ら ず 、 いつ も 極端 に 走 っ て しま う 。
# Ref | he is the kind of man who cannot do anything in moderation , but always goes to extremes .
# Hyp | he will _UNK as as he as as as as as . . _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.1053
# --------------------------------------------------
# Src | 道路 を 横断 する とき に は 注意 し なさ い 。
# Ref | you must be careful in crossing the road .
# Hyp | take care when when in the . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.3333
# --------------------------------------------------
# Src | 自分 の こと だけ 気 に かけ ろ ！
# Ref | mind your own business !
# Hyp | don &apos;t notice notice ! ! _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.2000
# --------------------------------------------------
# Src | 友人 は マイ カー を 欲し が っ て い る 。
# Ref | my friend wants a car of his own .
# Hyp | the are _UNK in in in in . _EOS
# --------------------------------------------------
# precision | 0.1111
# recall | 0.1111
# --------------------------------------------------
# Src | 彼女 は 私 の ひじ を 引っ張 っ た 。
# Ref | she gave a pluck at my elbow .
# Hyp | she girl my my . . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3750
# --------------------------------------------------
# Src | 何 が 起こ ろ う と も 、 私 は あなた の 味方 を する 。
# Ref | i will stand by you whatever happens .
# Hyp | what i , i , i &apos;ll . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2500
# --------------------------------------------------
# Src | コーヒー を 飲 み ま す か 。
# Ref | will you have some coffee ?
# Hyp | have you some some drink ? _EOS
# --------------------------------------------------
# precision | 0.5714
# recall | 0.6667
# --------------------------------------------------
# Src | 気持ち を 御 察し し ま す 。
# Ref | i understand how you feel .
# Hyp | i &apos;ll make you and . . _EOS
# --------------------------------------------------
# precision | 0.3750
# recall | 0.5000
# --------------------------------------------------
# Src | にわか 雨 に な る らし い で す よ 。
# Ref | they say we &apos;re going to get some showers .
# Hyp | it &apos;s not a a &apos;s a . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.1000
# --------------------------------------------------
# Src | 何事 も 最初 が 肝心 だ よ な 。
# Ref | whatever you &apos;re doing , starting off on the right foot is essential .
# Hyp | too can too too first say _UNK . . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.0714
# --------------------------------------------------
# Src | その 語 は 誤用 さ れ やす い 。
# Ref | the word lends itself to misuse by beginners .
# Hyp | the _UNK is _UNK in . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2222
# --------------------------------------------------
# Src | 彼 ら は 設計 図 どおり に 船 を 作 っ た 。
# Ref | they built the ship in accordance with the plans .
# Hyp | they rose _UNK _UNK _UNK _UNK _UNK . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2000
# --------------------------------------------------
# Src | ほんの ２、３ 日 前 に 彼女 に 会 っ た 。
# Ref | i saw her just the other day .
# Hyp | she last her before her her her her . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2500
# --------------------------------------------------
# Src | それ は どの ゲート で す か 。
# Ref | which gate is that ?
# Hyp | what it it gold ? _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.2000
# --------------------------------------------------
# Src | 私 は 何 と し て も 酒 を 止め る つもり で す 。
# Ref | i will give up drinking at any cost .
# Hyp | i &apos;m enough to to to tomorrow . . _EOS
# --------------------------------------------------
# precision | 0.2000
# recall | 0.2222
# --------------------------------------------------
# Src | 夜 の ツアー は あ り ま す か 。
# Ref | do you offer any night tours ?
# Hyp | how many the are ? ? _EOS
# --------------------------------------------------
# precision | 0.1429
# recall | 0.1429
# --------------------------------------------------
# Src | もっと 分別 が あ っ て も い い 年頃 だ よ 。
# Ref | you &apos;re old enough to know better .
# Hyp | i can &apos;t you that that that that . . . _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.2500
# --------------------------------------------------
# Src | この 停留 所 から ５ 番 目 の バス に 乗り なさ い 。
# Ref | take a no . 5 bus at this bus stop .
# Hyp | may get the the the the next next . _EOS
# --------------------------------------------------
# precision | 0.1000
# recall | 0.0909
# --------------------------------------------------
# Src | 彼 に は お 金 が 足り な い よう だっ た 。
# Ref | it seemed that he was short of money .
# Hyp | he had not be a . . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2222
# --------------------------------------------------
# Src | 彼 は 彼女 を 援助 し て や る 必要 が あ り ま す か 。
# Ref | does he need to help her ?
# Hyp | is he have you you you ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 軽 い 風邪 で す 。
# Ref | it &apos;s only a slight cold .
# Hyp | lot &apos;s cold @-@ cold @-@ _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.2857
# --------------------------------------------------
# Src | サッカー チーム 全体 が 優勝 し て 浮き浮き し て た 。
# Ref | the whole soccer team was on cloud nine after winning the championship .
# Hyp | _UNK _UNK were were the _UNK . _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.1538
# --------------------------------------------------
# Src | この 町 は 気 に 入 り ま し た か 。
# Ref | how do you like this town ?
# Hyp | how there the a notice picture ? _EOS
# --------------------------------------------------
# precision | 0.2500
# recall | 0.2857
# --------------------------------------------------
# Src | 冬 は 過ぎ去 っ た 。
# Ref | winter is gone .
# Hyp | the _UNK ate tennis . _EOS
# --------------------------------------------------
# precision | 0.1667
# recall | 0.2500
# --------------------------------------------------
# Src | 彼 の 助け 無し に は 、 や っ て いけ な い 。
# Ref | i cannot manage without his support .
# Hyp | you can &apos;t help to . . _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.1429
# --------------------------------------------------
# Src | この ホール は 最大 で １０００ 人 収容 でき る 。
# Ref | this hall holds a maximum of 1,000 people .
# Hyp | this cage is several from the sea . _EOS
# --------------------------------------------------
# precision | 0.2222
# recall | 0.2222
# --------------------------------------------------
# Src | 天気 予報 は どう で し た か 。
# Ref | what was the weather report ?
# Hyp | what did the ? ? _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5000
# --------------------------------------------------
# Src | 再三 彼 ら を 招待 し た が 決して こ な かっ た 。
# Ref | time after time i &apos;ve invited them to come over and visit us but time and time again they &apos;ve never come .
# Hyp | i had never _UNK the the the . . _EOS
# --------------------------------------------------
# precision | 0.3000
# recall | 0.1304
# --------------------------------------------------
# Src | 誰 も が 彼 の 技術 を 認め た 。
# Ref | everyone recognized his skill .
# Hyp | everybody left his his his his his _EOS
# --------------------------------------------------
# precision | 0.1250
# recall | 0.2000
# --------------------------------------------------
# Src | 貴方 は 、 明日 学校 に 行 く だ ろ う 。
# Ref | you &apos;ll go to school tomorrow .
# Hyp | you will soon go for you . . _EOS
# --------------------------------------------------
# precision | 0.3333
# recall | 0.4286
# --------------------------------------------------
# Src | この データ は その 議論 に と っ て 重要 だ 。
# Ref | this data is immaterial to the argument .
# Hyp | this is is the the the . _EOS
# --------------------------------------------------
# precision | 0.5000
# recall | 0.5000
# --------------------------------------------------
# Src | 彼女 と は よく 会 い ま す か 。
# Ref | do you see her often ?
# Hyp | will she you play her ? _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.5000
# --------------------------------------------------
# Src | 彼 ら は 容易 な ら ぬ 事態 に 直面 し て い る 。
# Ref | they are faced with a serious situation .
# Hyp | they are _UNK of the . _EOS
# --------------------------------------------------
# precision | 0.4286
# recall | 0.3750
# --------------------------------------------------
# Src | 多く の 時間 が 無駄 に な っ た 。
# Ref | much time was wasted .
# Hyp | many &apos;s time his his . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.4000
# --------------------------------------------------
# Src | 僕 の もの は 全て 君 の 物 だ 。
# Ref | whatever i have is yours .
# Hyp | my garden is your your . _EOS
# --------------------------------------------------
# precision | 0.2857
# recall | 0.3333
# --------------------------------------------------
# Src | ステーキ は 中位 で 焼 い て くださ い 。
# Ref | i like my steak medium .
# Hyp | i like my medium medium . _EOS
# --------------------------------------------------
# precision | 0.7143
# recall | 0.8333
# sentences matching filter = 500
